# %% [markdown]
# # Adverse Selection Detection — MLB Game Markets (KXMLBGAME)
#
# **Applying Dalen (2025) RN-JD calibration to Kalshi baseball game winner markets**
#
# Reference: *Toward Black-Scholes for Prediction Markets* (arXiv:2510.15205)
#
# ---
#
# ### Why Sports?
# Game outcomes are **news-driven**: scores update in real time, and prices jump when
# runs are scored or key events occur. Live bettors may have information advantages
# (streaming delay, faster data). Each game is a binary market (Team A wins / Team B wins)
# with high volume on playoff and marquee matchups.
#
# **To fetch more data:** run `python scripts/fetch_mlb_election.py` from the project root.
#
# ### Structure
# 1. Data loading
# 2. RN-JD calibration
# 3. AS detection showcase
# 4. Fill toxicity validation
# 5. Market-making backtest
# 6. Threshold sweep
# 7. Summary

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats as sp_stats

from src.as_detector import run_as_detection, run_all_tickers, ASResult
from src.mm_backtest import (
    compare_strategies, compare_all_tickers,
    sweep_thresholds, backtest_mm, analyse_fill_toxicity,
)

plt.rcParams.update({"figure.figsize": (14, 5), "axes.grid": True, "grid.alpha": 0.3, "font.size": 11})

import glob
CACHE = os.path.join('..', 'cache', 'kalshi_hf_mlb')
all_files = sorted(glob.glob(os.path.join(CACHE, '*_trades.parquet')))
print(f"Found {len(all_files)} parquet files")

data = {}
for f in all_files:
    tkr = os.path.basename(f).replace("_trades.parquet", "")
    df = pd.read_parquet(f).sort_values("timestamp").reset_index(drop=True)
    if len(df) >= 250:
        data[tkr] = df

data = dict(sorted(data.items(), key=lambda x: -len(x[1])))
print(f"Loaded {len(data)} tickers with >= 250 trades")
print(f"Total trades: {sum(len(v) for v in data.values()):,}")
for tkr, df in list(data.items())[:15]:
    print(f"  {tkr:<45s}  {len(df):>6,} trades  [{df['mid_price'].min():.2f} - {df['mid_price'].max():.2f}]")
if len(data) > 15:
    print(f"  ... and {len(data) - 15} more tickers")

if len(data) == 0:
    print("\nNo data. Run: python scripts/fetch_mlb_election.py")
# Out:
# Found 40 parquet files
# Loaded 40 tickers with >= 250 trades
# Total trades: 714,486
#   KXMLBGAME-25OCT27TORLAD-LAD                    52,362 trades  [0.30 - 0.99]
#   KXMLBGAME-25OCT27TORLAD-TOR                    44,406 trades  [0.01 - 0.70]
#   KXMLBGAME-25OCT24LADTOR-LAD                    37,784 trades  [0.01 - 0.81]
#   KXMLBGAME-25OCT28TORLAD-LAD                    29,600 trades  [0.01 - 0.75]
#   KXMLBGAME-25OCT31LADTOR-TOR                    28,911 trades  [0.01 - 0.74]
#   KXMLBGAME-25OCT31LADTOR-LAD                    25,872 trades  [0.50 - 0.99]
#   KXMLBGAME-25OCT29TORLAD-LAD                    25,114 trades  [0.01 - 0.73]
#   KXMLBGAME-25OCT15TORSEA-SEA                    20,621 trades  [0.01 - 0.83]
#   KXMLBGAME-25OCT29TORLAD-TOR                    20,537 trades  [0.30 - 0.99]
#   KXMLBGAME-25OCT19SEATOR-SEA                    20,047 trades  [0.01 - 0.73]
#   KXMLBGAME-25OCT28TORLAD-TOR                    19,787 trades  [0.21 - 0.99]
#   KXMLBGAME-25OCT09PHILAD-LAD                    19,544 trades  [0.28 - 0.99]
#   KXMLBGAME-25OCT08SEADET-SEA                    19,129 trades  [0.01 - 0.90]
#   KXMLBGAME-25OCT25LADTOR-LAD                    17,984 trades  [0.40 - 0.99]
#   KXMLBGAME-25OCT14LADMIL-LAD                    17,830 trades  [0.37 - 0.99]
#   ... and 25 more tickers

# %% [markdown]
# ## 2. RN-JD Calibration

# %%
all_as = run_all_tickers(data, em_window=200, em_iterations=8)
print(f"Calibrated {len(all_as)} tickers")

if all_as:
    cal_rows = [ar.calibration_summary for tkr, ar in sorted(all_as.items(), key=lambda x: -len(x[1].prices))]
    cal_df = pd.DataFrame(cal_rows)
    cols = ["ticker", "n_trades", "mean_sigma_b", "mean_lambda", "n_jumps_detected", "n_bursts_detected", "pct_flagged"]
    print(cal_df[cols].to_string(index=False, float_format="%.5f"))
# Out:
# [2026-03-03 03:43:13 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT27TORLAD-LAD: 52362 trades, 1157 jumps (γ>0.5), 5483 bursts, 1085 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00574
# [2026-03-03 03:43:22 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT27TORLAD-TOR: 44406 trades, 1585 jumps (γ>0.5), 5012 bursts, 1475 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01023
# [2026-03-03 03:43:30 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT24LADTOR-LAD: 37784 trades, 400 jumps (γ>0.5), 2321 bursts, 358 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00209
# [2026-03-03 03:43:36 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT28TORLAD-LAD: 29600 trades, 584 jumps (γ>0.5), 2662 bursts, 545 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00272
# [2026-03-03 03:43:42 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT31LADTOR-TOR: 28911 trades, 518 jumps (γ>0.5), 2023 bursts, 489 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00352
# [2026-03-03 03:43:47 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT31LADTOR-LAD: 25872 trades, 564 jumps (γ>0.5), 1720 bursts, 493 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00385
# [2026-03-03 03:43:52 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT29TORLAD-LAD: 25114 trades, 422 jumps (γ>0.5), 1652 bursts, 399 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00227
# [2026-03-03 03:43:56 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT15TORSEA-SEA: 20621 trades, 736 jumps (γ>0.5), 2179 bursts, 700 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00409
# [2026-03-03 03:44:00 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT29TORLAD-TOR: 20537 trades, 1455 jumps (γ>0.5), 2008 bursts, 1394 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.01135
# [2026-03-03 03:44:04 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT19SEATOR-SEA: 20047 trades, 617 jumps (γ>0.5), 1855 bursts, 545 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00618
# [2026-03-03 03:44:08 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT28TORLAD-TOR: 19787 trades, 792 jumps (γ>0.5), 2118 bursts, 749 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00518
# [2026-03-03 03:44:12 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT09PHILAD-LAD: 19544 trades, 825 jumps (γ>0.5), 2182 bursts, 757 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01342
# [2026-03-03 03:44:16 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT08SEADET-SEA: 19129 trades, 632 jumps (γ>0.5), 3037 bursts, 565 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00749
# [2026-03-03 03:44:20 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT25LADTOR-LAD: 17984 trades, 1259 jumps (γ>0.5), 1696 bursts, 1189 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01125
# [2026-03-03 03:44:23 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT14LADMIL-LAD: 17830 trades, 883 jumps (γ>0.5), 1711 bursts, 822 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00765
# [2026-03-03 03:44:27 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT08TORNYY-TOR: 16875 trades, 818 jumps (γ>0.5), 2418 bursts, 743 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.01246
# [2026-03-03 03:44:30 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OCT08TORNYY-NYY: 16779 trades, 689 jumps (γ>0.5), 2418 bursts, 619 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.01146
# [2026-03-03 03:44:33 UTC] [INFO] tauroi.as_detector — AS detection KXMLBGAME-25OC
# KXMLBGAME-25OCT13LADMIL-MIL     10814       0.00017      0.01438               756               1363      6.63954
# KXMLBGAME-25OCT17MILLAD-MIL     10675       0.00018      0.01567              1263               1224     11.25995
# KXMLBGAME-25OCT12SEATOR-TOR     10201       0.00018      0.01412               669                949      5.99941
# KXMLBGAME-25OCT13SEATOR-SEA      9552       0.00020      0.02641              1465               1288     14.57286
# KXMLBGAME-25OCT17MILLAD-LAD      9464       0.00015      0.02143              1077               1260     10.78825
# KXMLBGAME-25OCT16TORSEA-TOR      9134       0.00019      0.01899               812                942      7.97022
# KXMLBGAME-25OCT19SEATOR-TOR      8584       0.00016      0.02693               958               1195     10.27493
# KXMLBGAME-25OCT09MILCHC-CHC      6607       0.00021      0.02905               832               1029     11.04889

# %% [markdown]
# ## 3. AS Detection Showcase

# %%
if all_as:
    showcase_tkr = max(all_as.keys(), key=lambda k: len(all_as[k].prices))
    ar = all_as[showcase_tkr]
    fig, axes = plt.subplots(4, 1, figsize=(16, 12), sharex=True)
    ts = pd.to_datetime(ar.timestamps)

    axes[0].plot(ts, ar.prices, color="#2c3e50", lw=0.8, alpha=0.8)
    em = ar.as_score > 0.9
    axes[0].scatter(ts[em], ar.prices[em], color="red", s=20, alpha=0.6, zorder=5, label=f"AS events ({em.sum()})")
    axes[0].set_ylabel("Price"); axes[0].set_title(showcase_tkr, fontweight="bold"); axes[0].legend()

    axes[1].fill_between(ts, 0, ar.gamma, color="#e74c3c", alpha=0.4)
    axes[1].axhline(0.6, color="red", ls="--"); axes[1].set_ylabel("gamma_t"); axes[1].set_ylim(0, 1.05)

    axes[2].plot(ts, ar.arrival_rate_ratio, color="#3498db", lw=0.7)
    axes[2].axhline(3.0, color="orange", ls="--"); axes[2].set_ylabel("Arrival rate ratio")

    axes[3].fill_between(ts, 0, ar.as_score, color="#9b59b6", alpha=0.4)
    axes[3].axhline(0.9, color="purple", ls="--"); axes[3].set_ylabel("AS score"); axes[3].set_xlabel("Time")
    axes[3].set_ylim(0, 1.05)

    for a in axes:
        a.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d %H:%M"))
    plt.tight_layout()
    os.makedirs("../figures", exist_ok=True)
    plt.savefig("../figures/sports_as_showcase.png", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 4. Fill Toxicity Validation

# %%
if all_as:
    print("Fill Toxicity — Flagged vs Unflagged")
    print("=" * 90)
    for tkr in list(all_as.keys())[:8]:
        ar = all_as[tkr]
        tox = analyse_fill_toxicity(ar, mtm_horizons=[10, 30, 60, 120])
        if tox.empty: continue
        print(f"\n{tkr} ({len(ar.prices):,} trades)")
        print(tox.to_string(index=False, float_format="%.4f"))
# Out:
# Fill Toxicity — Flagged vs Unflagged
# ==========================================================================================
#
# KXMLBGAME-25OCT27TORLAD-LAD (52,362 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        310        14533             0.0236               0.0119 1.9791 12.0692   0.0000
#              30        310        14533             0.0286               0.0165 1.7306  8.7228   0.0000
#              60        310        14533             0.0313               0.0218 1.4397  5.5632   0.0000
#             120        310        14533             0.0370               0.0307 1.2072  2.8731   0.0020
#
# KXMLBGAME-25OCT27TORLAD-TOR (44,406 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        514        14529             0.0262               0.0121 2.1606 18.0353   0.0000
#              30        514        14529             0.0336               0.0167 2.0167 15.3917   0.0000
#              60        514        14529             0.0410               0.0226 1.8125 12.9936   0.0000
#             120        514        14529             0.0460               0.0320 1.4350  7.8972   0.0000
#
# KXMLBGAME-25OCT24LADTOR-LAD (37,784 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10         63         4915             0.0121               0.0092 1.3138  2.0048   0.0225
#              30         63         4915             0.0140               0.0117 1.1917  1.2185   0.1115
#              60         63         4915             0.0144               0.0139 1.0382  0.2367   0.4065
#             120         63         4915             0.0173               0.0181 0.9553 -0.2555   0.6008
#
# KXMLBGAME-25OCT28TORLAD-LAD (29,600 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        153         5513             0.0325               0.0096 3.3825 16.6760   0.0000
#              30        153         5513             0.0352               0.0122 2.8764 11.5944   0.0000
#              60        153         5513             0.0384               0.0139 2.7743 11.4479   0.0000
#             120        153         5513             0.0389               0.0171 2.2678  9.1156   0.0000
#
# KXMLBGAME-25OCT31LADTOR-TOR (28,911 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        132         6195             0.0411               0.0129 3.1799 10.8114   0.0000
#              30        132         6195             0.0523               0.0169 3.1030 10.7466   0.0000
#              60        132         6195             0.0758               0.0198 3.8259 15.1891   0.0000
#             120        132         6195             0.0609               0.0255 2.3882  9.2935   0.0000
#
# KXMLBGAME-25OCT31LADTOR-LAD (25,872 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        179         5269             0.0305               0.0120 2.5350  9.7302   0.0000
#              30        179         5269             0.0277               0.0162 1.7062  4.9231   0.0000
#              60        179         5269             0.0320               0.0198 1.6174  4.6889   0.0000
#             120        179         5269             0.0308               0.0273 1.1263  1.1735   0.1203
#
# KXMLBGAME-25OCT29TORLAD-LAD (25,114 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        120         4422             0.0193               0.0076 2.5391 13.5719   0.0000
#              30        120         4422             0.0243               0.0094 2.6010 13.4047   0.0000
#              60        120         4422             0.0285               0.0113 2.5145 12.3515   0.0000
#             120        120         4422             0.0416               0.0154 2.6974 14.0707   0.0000
#
# KXMLBGAME-25OCT15TORSEA-SEA (20,621 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        115         4153             0.0258               0.0121 2.1298  7.5992   0.0000
#              30        115         4153             0.0218               0.0146 1.4965  3.5734   0.0002
#              60        115         4153             0.0258               0.0169 1.5242  3.7689   0.0001
#             120        115         4153             0.0276               0.0212 1.2982  2.1358   0.0164

# %% [markdown]
# ## 5. Market-Making Backtest

# %%
if all_as:
    comparisons = compare_all_tickers(all_as, as_threshold=0.9, half_spread_cents=2.0, mtm_horizon_trades=60)
    comp_df = pd.DataFrame([c.summary for c in comparisons.values()]).sort_values("naive_pnl_c", ascending=False)

    print("Naive vs AS-Informed (tau=0.9)")
    print("=" * 100)
    print(comp_df.to_string(index=False, float_format="%.2f"))

    nt = comp_df.naive_pnl_c.sum(); it = comp_df.informed_pnl_c.sum()
    print(f"\nNaive total: {nt:.1f}c | Informed total: {it:.1f}c | Delta: {it-nt:+.1f}c")
    improved = sum(1 for c in comparisons.values() if c.pnl_improvement > 0)
    print(f"Improved: {improved}/{len(comparisons)} tickers")
# Out:
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT27TORLAD-LAD: naive=11819.0c (5321 fills) | informed=11828.3c (5258 fills) | improvement=9.3c | avoided=63 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT27TORLAD-TOR: naive=10906.3c (5010 fills) | informed=10777.1c (4906 fills) | improvement=-129.2c | avoided=104 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT24LADTOR-LAD: naive=2826.4c (1189 fills) | informed=2814.6c (1186 fills) | improvement=-11.8c | avoided=3 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT28TORLAD-LAD: naive=2213.8c (994 fills) | informed=2105.4c (975 fills) | improvement=-108.4c | avoided=19 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT31LADTOR-TOR: naive=3206.3c (1567 fills) | informed=2908.3c (1546 fills) | improvement=-298.0c | avoided=21 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT31LADTOR-LAD: naive=2522.4c (1259 fills) | informed=2542.6c (1245 fills) | improvement=20.2c | avoided=14 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT29TORLAD-LAD: naive=1360.9c (579 fills) | informed=1347.4c (566 fills) | improvement=-13.5c | avoided=13 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT15TORSEA-SEA: naive=2962.0c (1349 fills) | informed=2970.4c (1324 fills) | improvement=8.3c | avoided=25 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT29TORLAD-TOR: naive=2184.9c (977 fills) | informed=2170.4c (964 fills) | improvement=-14.5c | avoided=13 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT19SEATOR-SEA: naive=2057.6c (930 fills) | informed=2048.7c (923 fills) | improvement=-9.0c | avoided=7 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT28TORLAD-TOR: naive=3625.1c (1547 fills) | informed=3620.9c (1533 fills) | improvement=-4.2c | avoided=14 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT09PHILAD-LAD: naive=3545.0c (1637 fills) | informed=3558.2c (1614 fills) | improvement=13.2c | avoided=23 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT08SEADET-SEA: naive=3215.7c (1393 fills) | informed=3215.2c (1387 fills) | improvement=-0.5c | avoided=6 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT25LADTOR-LAD: naive=1913.2c (1032 fills) | informed=1858.3c (973 fills) | improvement=-54.9c | avoided=59 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT14LADMIL-LAD: naive=2534.1c (1048 fills) | informed=2520.6c (1030 fills) | improvement=-13.5c | avoided=18 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT08TORNYY-TOR: naive=3526.5c (1515 fills) | informed=3409.7c (1488 fills) | improvement=-116.8c | avoided=27 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT08TORNYY-NYY: naive=1609.5c (746 fills) | informed=1611.3c (737 fills) | improvement=1.8c | avoided=9 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT15TORSEA-TOR: naive=2954.1c (1450 fills) | informed=2897.4c (1422 fills) | improvement=-56.7c | avoided=28 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT14LADMIL-MIL: naive=1434.0c (657 fills) | informed=1420.0c (646 fills) | improvement=-14.0c | avoided=11 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT09MILCHC-MIL: naive=2041.1c (921 fills) | informed=2053.2c (913 fills) | improvement=12.1c | avoided=8 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT09PHILAD-PHI: naive=2591.9c (1171 fills) | informed=2607.4c (1132 fills) | improvement=15.5c | avoided=39 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT08SEADET-DET: naive=3480.6c (1462 fills) | informed=3495.4c (1440 fills) | improvement=14.8c | avoided=22 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT24LADTOR-TOR: naive=2375.0c (982 fills) | informed=2339.9c (970 fills) | improvement=-35.1c | avoided=12 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT25LADTOR-TOR: naive=1615.7c (884 fills) | informed=1587.5c (848 fills) | improvement=-28.2c | avoided=36 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT17TORSEA-TOR: naive=2657.1c (1435 fills) | informed=2579.6c (1422 fills) | improvement=-77.5c | avoided=13 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT16MILLAD-MIL: naive=1224.6c (609 fills) | informed=1209.7c (592 fills) | improvement=-14.9c | avoided=17 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT13SEATOR-TOR: naive=2097.5c (936 fills) | informed=2039.3c (908 fills) | improvement=-58.2c | avoided=28 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT17TORSEA-SEA: naive=2497.2c (1225 fills) | informed=2496.6c (1217 fills) | improvement=-0.7c | avoided=8 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT12SEATOR-SEA: naive=2359.9c (1146 fills) | informed=2299.6c (1111 fills) | improvement=-60.4c | avoided=35 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT16MILLAD-LAD: naive=1283.1c (562 fills) | informed=1273.2c (542 fills) | improvement=-9.9c | avoided=20 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT13LADMIL-LAD: naive=1535.9c (740 fills) | informed=1543.5c (720 fills) | improvement=7.6c | avoided=20 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT16TORSEA-SEA: naive=1393.0c (636 fills) | informed=1346.2c (597 fills) | improvement=-46.8c | avoided=39 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT13LADMIL-MIL: naive=1377.0c (649 fills) | informed=1353.0c (637 fills) | improvement=-23.9c | avoided=12 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT17MILLAD-MIL: naive=1180.6c (475 fills) | informed=1161.5c (465 fills) | improvement=-19.1c | avoided=10 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT12SEATOR-TOR: naive=1956.7c (856 fills) | informed=1923.8c (826 fills) | improvement=-33.0c | avoided=30 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT13SEATOR-SEA: naive=2030.6c (951 fills) | informed=1976.9c (872 fills) | improvement=-53.7c | avoided=79 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT17MILLAD-LAD: naive=1107.4c (440 fills) | informed=1056.2c (416 fills) | improvement=-51.2c | avoided=24 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT16TORSEA-TOR: naive=1880.6c (837 fills) | informed=1847.0c (807 fills) | improvement=-33.6c | avoided=30 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT19SEATOR-TOR: naive=1383.2c (618 fills) | informed=1370.2c (590 fills) | improvement=-13.0c | avoided=28 toxic fills
# [2026-03-03 03:45:33 UTC] [INFO] tauroi.mm_backtest — Comparison KXMLBGAME-25OCT09MILCHC-CHC: naive=1063.4c (519 fills) | informed=1032.2c (477 fills) | improvement=-31.2c | avoided=42 toxic fills
# Naive vs AS-Informed (tau=0.9)
# ====================================================================================================
#                      ticker  naive_pnl_c  informed_pnl_c  improvement_c  naive_fills  informed_fills  fills_avoided  naive_win_rate  informed_win_rate
# KXMLBGAME-25OCT27TORLAD-LAD     11819.01        11828.28           9.27         5321            5258             63            0.85               0.85
# KXMLBGAME-25OCT27TORLAD-TOR     10906.32        10777.14        -129.18         5010            4906            104            0.84               0.84
# KXMLBGAME-25OCT28TORLAD-TOR      3625.12         3620.92          -4.20         1547            1533             14            0.86               0.86
# KXMLBGAME-25OCT09PHILAD-LAD      3544.99         3558.18          13.19         1637            1614             23            0.82               0.82
# KXMLBGAME-25OCT08TORNYY-TOR      3526.45         3409.68        -116.78         1515            1488             27            0.86               0.86
# KXMLBGAME-25OCT08SEADET-DET      3480.56         3495.40          14.83         1462            1440             22            0.84               0.84
# KXMLBGAME-25OCT08SEADET-SEA      3215.72         3215.22          -0.50         1393            1387              6            0.82               0.82
# KXMLBGAME-25OCT31LADTOR-TOR      3206.32         2908.34        -297.98         1567            1546             21            0.83               0.84
# KXMLBGAME-25OCT15TORSEA-SEA      2962.05         2970.39           8.34         1349            1324             25            0.87               0.87
# KXMLBGAME-25OCT15TORSEA-TOR      2954.14         2897.44         -56.70         1450            1422             28            0.84               0.84
# KXMLBGAME-25OCT24LADTOR-LAD      2826.39         2814.61         -11.79         1189            1186              3            0.87               0.87
# Naive total: 105549.2c | Informed total: 104216.6c | Delta: -1332.6c
# Improved: 9/40 tickers

# %% [markdown]
# ## 6. Threshold Sweep

# %%
if all_as:
    sweep_tkr = max(all_as.keys(), key=lambda k: len(all_as[k].prices))
    sweep_df = sweep_thresholds(all_as[sweep_tkr], mtm_horizon_trades=60)
    print(f"Threshold sweep: {sweep_tkr}")
    print(sweep_df.to_string(index=False, float_format="%.2f"))

    fig, ax = plt.subplots(figsize=(10, 4))
    inf = sweep_df[sweep_df.strategy == "as_informed"]
    ax.plot(inf.threshold, inf.net_pnl_c, "o-", color="#2ecc71", lw=2)
    ax.axhline(sweep_df.iloc[0].net_pnl_c, color="red", ls="--", label="Naive")
    ax.set_xlabel("tau"); ax.set_ylabel("PnL (c)"); ax.set_title("PnL vs AS Threshold"); ax.legend()
    plt.tight_layout()
    plt.savefig("../figures/sports_threshold_sweep.png", dpi=150, bbox_inches="tight")
    plt.show()
# Out:
# Threshold sweep: KXMLBGAME-25OCT27TORLAD-LAD
#  threshold    strategy  n_fills  n_pulled  net_pnl_c  pnl_per_fill_c  win_rate  gross_spread_c  mtm_pnl_c  fees_c
#       0.00       naive     5321         0   11819.01            2.22      0.85        10642.00    3322.00 2144.99
#       0.10 as_informed     4397      6320   10433.06            2.37      0.87         8794.00    3418.00 1778.94
#       0.20 as_informed     4398      6309   10433.70            2.37      0.87         8796.00    3417.00 1779.30
#       0.30 as_informed     4401      6297   10443.70            2.37      0.87         8802.00    3422.00 1780.30
#       0.40 as_informed     5188      1099   11710.53            2.26      0.85        10376.00    3432.00 2097.47
#       0.50 as_informed     5191      1085   11696.32            2.25      0.85        10382.00    3413.00 2098.68
#       0.60 as_informed     5197      1054   11705.94            2.25      0.85        10394.00    3413.00 2101.06
#       0.70 as_informed     5258       283   11828.28            2.25      0.85        10516.00    3437.00 2124.72
#       0.80 as_informed     5260       267   11845.69            2.25      0.85        10520.00    3451.00 2125.31
#       0.90 as_informed     5261       260   11848.26            2.25      0.85        10522.00    3452.00 2125.74

# %% [markdown]
# ## 7. Summary

# %%
if all_as and comparisons:
    print("=" * 70)
    print("ADVERSE SELECTION — MLB GAME MARKETS SUMMARY")
    print("=" * 70)
    tt = sum(len(ar.prices) for ar in all_as.values())
    te = sum((ar.as_score > 0.9).sum() for ar in all_as.values())
    print(f"Tickers: {len(all_as)} | Trades: {tt:,} | AS events: {te:,} ({te/tt*100:.1f}%)")
    nt = sum(c.naive.net_pnl for c in comparisons.values())
    it = sum(c.informed.net_pnl for c in comparisons.values())
    print(f"Backtest (tau=0.9): Naive={nt:.1f}c Informed={it:.1f}c Delta={it-nt:+.1f}c")
    print(f"Improved: {sum(1 for c in comparisons.values() if c.pnl_improvement > 0)}/{len(comparisons)} tickers")
    print("=" * 70)
# Out:
# ======================================================================
# ADVERSE SELECTION — MLB GAME MARKETS SUMMARY
# ======================================================================
# Tickers: 40 | Trades: 714,486 | AS events: 30,912 (4.3%)
# Backtest (tau=0.9): Naive=105549.2c Informed=104216.6c Delta=-1332.6c
# Improved: 9/40 tickers
# ======================================================================
