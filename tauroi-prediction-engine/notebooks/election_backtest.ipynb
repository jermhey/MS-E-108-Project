# %% [markdown]
# # Adverse Selection Detection — 2024 Election Markets
#
# **Applying Dalen (2025) RN-JD calibration to Kalshi presidential & senate markets**
#
# Reference: *Toward Black-Scholes for Prediction Markets* (arXiv:2510.15205)
#
# ---
#
# ### Why Election Markets?
# Election night is **news-driven**: results arrive in batches, exit polls leak, and
# prices jump on new information. This creates ideal conditions for adverse selection —
# informed traders may react to early precinct data before public updates. We test
# the AS detector on 2024 state-level markets (PA, NV, VA, AZ, WI, IL, CO).
#
# ### Structure
# 1. Data loading
# 2. RN-JD calibration
# 3. AS detection showcase (most liquid: PA)
# 4. Fill toxicity validation
# 5. Market-making backtest (Naive vs AS-informed)
# 6. Threshold sweep
# 7. Cross-state co-jump analysis
# 8. Summary

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats as sp_stats

from src.as_detector import run_as_detection, run_all_tickers, ASResult
from src.mm_backtest import (
    compare_strategies, compare_all_tickers,
    sweep_thresholds, backtest_mm, analyse_fill_toxicity,
)

plt.rcParams.update({"figure.figsize": (14, 5), "axes.grid": True, "grid.alpha": 0.3, "font.size": 11})

import glob
CACHE = os.path.join('..', 'cache', 'kalshi_hf_election')
all_files = sorted(glob.glob(os.path.join(CACHE, '*_trades.parquet')))
print(f"Found {len(all_files)} parquet files")

data = {}
for f in all_files:
    tkr = os.path.basename(f).replace("_trades.parquet", "")
    df = pd.read_parquet(f).sort_values("timestamp").reset_index(drop=True)
    if len(df) >= 250:
        data[tkr] = df

data = dict(sorted(data.items(), key=lambda x: -len(x[1])))
print(f"Loaded {len(data)} tickers with >= 250 trades")
print(f"Total trades: {sum(len(v) for v in data.values()):,}")
for tkr, df in list(data.items())[:20]:
    print(f"  {tkr:<30s}  {len(df):>6,} trades  [{df['mid_price'].min():.2f} - {df['mid_price'].max():.2f}]")
# Out:
# Found 20 parquet files
# Loaded 17 tickers with >= 250 trades
# Total trades: 113,499
#   PRESPARTYPA-24-R                25,552 trades  [0.01 - 0.99]
#   PRESPARTYPA-24-D                18,620 trades  [0.01 - 0.55]
#   PRESPARTYNV-24-R                14,929 trades  [0.43 - 0.99]
#   PRESPARTYNV-24-D                11,599 trades  [0.01 - 0.57]
#   PRESPARTYVA-24-R                11,050 trades  [0.01 - 0.39]
#   PRESPARTYAZ-24-D                 8,452 trades  [0.01 - 0.36]
#   PRESPARTYAZ-24-R                 8,315 trades  [0.06 - 0.99]
#   PRESPARTYVA-24-D                 5,665 trades  [0.70 - 0.99]
#   SENATEWI-24-R                    2,727 trades  [0.01 - 0.89]
#   SENATEWI-24-D                    1,752 trades  [0.01 - 0.99]
#   PRESPARTYIL-24-R                 1,369 trades  [0.01 - 0.11]
#   PRESPARTYCO-24-R                 1,063 trades  [0.01 - 0.31]
#   PRESPARTYCO-24-D                   746 trades  [0.62 - 0.99]
#   PRESPARTYIL-24-D                   715 trades  [0.90 - 0.99]
#   PRESPARTYIN-24-D                   402 trades  [0.01 - 0.09]
#   PRESPARTYMO-24-D                   291 trades  [0.01 - 0.15]
#   PRESPARTYIN-24-R                   252 trades  [0.93 - 0.99]

# %% [markdown]
# ## 2. RN-JD Calibration

# %%
all_as = run_all_tickers(data, em_window=200, em_iterations=8)
print(f"Calibrated {len(all_as)} tickers")

cal_rows = [ar.calibration_summary for tkr, ar in sorted(all_as.items(), key=lambda x: -len(x[1].prices))]
cal_df = pd.DataFrame(cal_rows)
cols = ["ticker", "n_trades", "mean_sigma_b", "mean_lambda", "n_jumps_detected", "n_bursts_detected", "pct_flagged"]
print(cal_df[cols].to_string(index=False, float_format="%.5f"))
# Out:
# [2026-03-03 03:46:08 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYPA-24-R: 25552 trades, 4368 jumps (γ>0.5), 3306 bursts, 4206 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01725
# [2026-03-03 03:46:12 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYPA-24-D: 18620 trades, 3638 jumps (γ>0.5), 2708 bursts, 3456 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.02730
# [2026-03-03 03:46:16 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYNV-24-R: 14929 trades, 3084 jumps (γ>0.5), 1857 bursts, 2959 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01437
# [2026-03-03 03:46:18 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYNV-24-D: 11599 trades, 2545 jumps (γ>0.5), 1515 bursts, 2456 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01648
# [2026-03-03 03:46:21 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYVA-24-R: 11050 trades, 2540 jumps (γ>0.5), 1880 bursts, 2446 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.03090
# [2026-03-03 03:46:23 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYAZ-24-D: 8452 trades, 2058 jumps (γ>0.5), 1223 bursts, 1980 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01592
# [2026-03-03 03:46:25 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYAZ-24-R: 8315 trades, 1777 jumps (γ>0.5), 1013 bursts, 1709 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00573
# [2026-03-03 03:46:27 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYVA-24-D: 5665 trades, 1909 jumps (γ>0.5), 1157 bursts, 1857 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.01499
# [2026-03-03 03:46:28 UTC] [INFO] tauroi.as_detector — AS detection SENATEWI-24-R: 2727 trades, 989 jumps (γ>0.5), 595 bursts, 958 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00411
# [2026-03-03 03:46:28 UTC] [INFO] tauroi.as_detector — AS detection SENATEWI-24-D: 1752 trades, 711 jumps (γ>0.5), 523 bursts, 680 flagged (score>0.5), mean σ_b=0.0003, mean λ=0.00215
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYIL-24-R: 1369 trades, 740 jumps (γ>0.5), 233 bursts, 715 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00099
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYCO-24-R: 1063 trades, 599 jumps (γ>0.5), 216 bursts, 583 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00154
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYCO-24-D: 746 trades, 430 jumps (γ>0.5), 70 bursts, 421 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00079
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYIL-24-D: 715 trades, 404 jumps (γ>0.5), 85 bursts, 394 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00035
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYIN-24-D: 402 trades, 208 jumps (γ>0.5), 0 bursts, 206 flagged (score>0.5), mean σ_b=0.0002, mean λ=0.00051
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYMO-24-D: 291 trades, 146 jumps (γ>0.5), 0 bursts, 140 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00022
# [2026-03-03 03:46:29 UTC] [INFO] tauroi.as_detector — AS detection PRESPARTYIN-24-R: 252 trades, 143 jumps (γ>0.5), 0 bursts, 140 flagged (score>0.5), mean σ_b=0.0001, mean λ=0.00021
# Calibrated 17 tickers
#           ticker  n_trades  mean_sigma_b  mean_lambda  n_jumps_detected  n_bursts_detected  pct_flagged
# PRESPARTYPA-24-R     25552       0.00008      0.01725              4368               3306     16.46055
# PRESPARTYPA-24-D     18620       0.00010      0.02730              3638               2708     18.56069
# PRESPARTYNV-24-R     14929       0.00008      0.01437              3084               1857     19.82048
# PRESPARTYNV-24-D     11599       0.00011      0.01648              2545               1515     21.17424
# PRESPARTYVA-24-R     11050       0.00011      0.03090              2540               1880     22.13575
# PRESPARTYAZ-24-D      8452       0.00008      0.01592              2058               1223     23.42641
# PRESPARTYAZ-24-R      8315       0.00007      0.00573              1777               1013     20.55322
# PRESPARTYVA-24-D      5665       0.00009      0.01499              1909               1157     32.78023
#    SENATEWI-24-R      2727       0.00021      0.00411               989                595     35.13018
#    SENATEWI-24-D      1752       0.00026      0.00215               711                523     38.81279
# PRESPARTYIL-24-R      1369       0.00009      0.00099               740                233     52.22790
# PRESPARTYCO-24-R      1063       0.00009      0.00155               599                216     54.84478
# PRESPARTYCO-24-D       746       0.00009      0.00081               430                 70     56.43432
# PRESPARTYIL-24-D       715       0.00008      0.00037               404                 85     55.10490
# PRESPARTYIN-24-D       402       0.00016      0.00054               208                  0     51.24378
# PRESPARTYMO-24-D       291       0.00010      0.00025               146                  0     48.10997
# PRESPARTYIN-24-R       252       0.00013      0.00025               143                  0     55.55556

# %% [markdown]
# ## 3. AS Detection Showcase (PA Republican — Most Liquid)

# %%
showcase_tkr = max(all_as.keys(), key=lambda k: len(all_as[k].prices))
ar = all_as[showcase_tkr]
fig, axes = plt.subplots(4, 1, figsize=(16, 12), sharex=True)
ts = pd.to_datetime(ar.timestamps)

axes[0].plot(ts, ar.prices, color="#2c3e50", lw=0.8, alpha=0.8)
em = ar.as_score > 0.9
axes[0].scatter(ts[em], ar.prices[em], color="red", s=20, alpha=0.6, zorder=5, label=f"AS events ({em.sum()})")
axes[0].set_ylabel("Price"); axes[0].set_title(showcase_tkr, fontweight="bold"); axes[0].legend()

axes[1].fill_between(ts, 0, ar.gamma, color="#e74c3c", alpha=0.4)
axes[1].axhline(0.6, color="red", ls="--"); axes[1].set_ylabel("gamma_t"); axes[1].set_ylim(0, 1.05)

axes[2].plot(ts, ar.arrival_rate_ratio, color="#3498db", lw=0.7)
axes[2].axhline(3.0, color="orange", ls="--"); axes[2].set_ylabel("Arrival rate ratio")

axes[3].fill_between(ts, 0, ar.as_score, color="#9b59b6", alpha=0.4)
axes[3].axhline(0.9, color="purple", ls="--"); axes[3].set_ylabel("AS score"); axes[3].set_xlabel("Time")
axes[3].set_ylim(0, 1.05)

for a in axes:
    a.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d %H:%M"))
plt.tight_layout()
plt.savefig("../figures/election_as_showcase.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 4. Fill Toxicity Validation

# %%
print("Fill Toxicity — Flagged vs Unflagged")
print("=" * 90)
for tkr in list(all_as.keys())[:10]:
    ar = all_as[tkr]
    tox = analyse_fill_toxicity(ar, mtm_horizons=[10, 30, 60, 120])
    if tox.empty: continue
    print(f"\n{tkr} ({len(ar.prices):,} trades)")
    print(tox.to_string(index=False, float_format="%.4f"))
# Out:
# Fill Toxicity — Flagged vs Unflagged
# ==========================================================================================
#
# PRESPARTYPA-24-R (25,552 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10       1505         5937             0.0147               0.0106 1.3780  9.9096   0.0000
#              30       1505         5937             0.0165               0.0123 1.3380  9.6655   0.0000
#              60       1505         5937             0.0178               0.0139 1.2837  8.5389   0.0000
#             120       1505         5937             0.0200               0.0166 1.2033  6.3881   0.0000
#
# PRESPARTYPA-24-D (18,620 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10       1424         4802             0.0181               0.0130 1.3919 10.1990   0.0000
#              30       1424         4802             0.0209               0.0155 1.3510  9.3911   0.0000
#              60       1424         4802             0.0228               0.0172 1.3254  8.9156   0.0000
#             120       1424         4802             0.0242               0.0201 1.2000  6.1803   0.0000
#
# PRESPARTYNV-24-R (14,929 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10       1186         4039             0.0172               0.0136 1.2656  6.1083   0.0000
#              30       1186         4039             0.0190               0.0163 1.1638  4.0728   0.0000
#              60       1186         4039             0.0213               0.0191 1.1164  3.1743   0.0008
#             120       1186         4039             0.0250               0.0241 1.0394  1.1471   0.1257
#
# PRESPARTYNV-24-D (11,599 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        988         3367             0.0172               0.0132 1.3018  6.8192   0.0000
#              30        988         3367             0.0191               0.0158 1.2078  4.9643   0.0000
#              60        988         3367             0.0232               0.0190 1.2228  5.6085   0.0000
#             120        988         3367             0.0281               0.0252 1.1156  2.9914   0.0014
#
# PRESPARTYVA-24-R (11,050 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        952         3046             0.0305               0.0186 1.6437 11.0585   0.0000
#              30        952         3046             0.0364               0.0213 1.7107 12.3867   0.0000
#              60        952         3046             0.0399               0.0234 1.7082 12.5091   0.0000
#             120        952         3046             0.0444               0.0279 1.5891 11.7256   0.0000
#
# PRESPARTYAZ-24-D (8,452 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        932         2369             0.0228               0.0157 1.4518  8.9289   0.0000
#              30        932         2369             0.0269               0.0189 1.4237  7.9158   0.0000
#              60        932         2369             0.0290               0.0220 1.3197  6.2942   0.0000
#             120        932         2369             0.0313               0.0249 1.2567  5.5264   0.0000
#
# PRESPARTYAZ-24-R (8,315 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        722         2230             0.0221               0.0144 1.5361  5.3443   0.0000
#              30        722         2230             0.0248               0.0171 1.4498  5.1531   0.0000
#              60        722         2230             0.0292               0.0203 1.4354  5.2702   0.0000
#             120        722         2230             0.0340               0.0238 1.4292  5.7240   0.0000
#
# PRESPARTYVA-24-D (5,665 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        668         1473             0.0187               0.0155 1.1998  3.3540   0.0004
#              30        668         1473             0.0219               0.0193 1.1375  2.4647   0.0069
#              60        668         1473             0.0270               0.0225 1.2001  3.4900   0.0002
#             120        668         1473             0.0333               0.0274 1.2156  3.9928   0.0000
#
# SENATEWI-24-R (2,727 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        460          741             0.0511               0.0383 1.3342  3.4283   0.0003
#              30        460          741             0.0697               0.0533 1.3088  3.4563   0.0003
#              60        460          741             0.0943               0.0702 1.3422  4.1129   0.0000
#             120        460          741             0.1360               0.1079 1.2610  3.5329   0.0002
#
# SENATEWI-24-D (1,752 trades)
#  horizon_trades  n_flagged  n_unflagged  mean_move_flagged  mean_move_unflagged  ratio  t_stat  p_value
#              10        306          469             0.0746               0.0409 1.8233  5.7061   0.0000
#              30        306          469             0.0997               0.0632 1.5771  4.6081   0.0000
#              60        306          469             0.1393               0.0865 1.6105  4.9594   0.0000
#             120        306          469             0.1838               0.1446 1.2706  2.8678   0.0021

# %% [markdown]
# ## 5. Market-Making Backtest

# %%
comparisons = compare_all_tickers(all_as, as_threshold=0.9, half_spread_cents=2.0, mtm_horizon_trades=60)
comp_df = pd.DataFrame([c.summary for c in comparisons.values()]).sort_values("naive_pnl_c", ascending=False)

print("Naive vs AS-Informed (tau=0.9)")
print("=" * 100)
print(comp_df.to_string(index=False, float_format="%.2f"))

nt = comp_df.naive_pnl_c.sum(); it = comp_df.informed_pnl_c.sum()
print(f"\nNaive total: {nt:.1f}c | Informed total: {it:.1f}c | Delta: {it-nt:+.1f}c")
print(f"Improved: {sum(1 for c in comparisons.values() if c.pnl_improvement > 0)}/{len(comparisons)} tickers")
# Out:
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYPA-24-R: naive=5204.3c (2316 fills) | informed=4936.3c (2181 fills) | improvement=-267.9c | avoided=135 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYPA-24-D: naive=3838.1c (1912 fills) | informed=3642.0c (1748 fills) | improvement=-196.2c | avoided=164 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYNV-24-R: naive=3995.8c (1907 fills) | informed=3898.5c (1833 fills) | improvement=-97.2c | avoided=74 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYNV-24-D: naive=2193.1c (1154 fills) | informed=2106.4c (1096 fills) | improvement=-86.7c | avoided=58 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYVA-24-R: naive=2419.9c (1441 fills) | informed=2165.2c (1246 fills) | improvement=-254.7c | avoided=195 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYAZ-24-D: naive=2145.7c (1041 fills) | informed=1964.3c (937 fills) | improvement=-181.4c | avoided=104 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYAZ-24-R: naive=1947.4c (976 fills) | informed=1813.3c (888 fills) | improvement=-134.1c | avoided=88 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYVA-24-D: naive=1681.3c (775 fills) | informed=1421.2c (689 fills) | improvement=-260.1c | avoided=86 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison SENATEWI-24-R: naive=82.8c (520 fills) | informed=119.0c (419 fills) | improvement=36.2c | avoided=101 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison SENATEWI-24-D: naive=-219.2c (347 fills) | informed=-138.5c (246 fills) | improvement=80.7c | avoided=101 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYIL-24-R: naive=290.6c (114 fills) | informed=265.8c (104 fills) | improvement=-24.8c | avoided=10 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYCO-24-R: naive=139.1c (91 fills) | informed=126.7c (66 fills) | improvement=-12.3c | avoided=25 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYCO-24-D: naive=185.1c (84 fills) | informed=185.1c (84 fills) | improvement=0.0c | avoided=0 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYIL-24-D: naive=149.2c (57 fills) | informed=149.2c (57 fills) | improvement=0.0c | avoided=0 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYIN-24-D: naive=180.4c (67 fills) | informed=180.4c (67 fills) | improvement=0.0c | avoided=0 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYMO-24-D: naive=86.4c (42 fills) | informed=86.4c (42 fills) | improvement=0.0c | avoided=0 toxic fills
# [2026-03-03 03:46:31 UTC] [INFO] tauroi.mm_backtest — Comparison PRESPARTYIN-24-R: naive=99.3c (35 fills) | informed=99.3c (35 fills) | improvement=0.0c | avoided=0 toxic fills
# Naive vs AS-Informed (tau=0.9)
# ====================================================================================================
#           ticker  naive_pnl_c  informed_pnl_c  improvement_c  naive_fills  informed_fills  fills_avoided  naive_win_rate  informed_win_rate
# PRESPARTYPA-24-R      5204.29         4936.35        -267.94         2316            2181            135            0.84               0.85
# PRESPARTYNV-24-R      3995.79         3898.55         -97.24         1907            1833             74            0.80               0.81
# PRESPARTYPA-24-D      3838.13         3641.97        -196.16         1912            1748            164            0.78               0.79
# PRESPARTYVA-24-R      2419.90         2165.20        -254.70         1441            1246            195            0.69               0.70
# PRESPARTYNV-24-D      2193.11         2106.44         -86.67         1154            1096             58            0.73               0.73
# PRESPARTYAZ-24-D      2145.67         1964.31        -181.36         1041             937            104            0.73               0.74
# PRESPARTYAZ-24-R      1947.37         1813.28        -134.09          976             888             88            0.79               0.79
# PRESPARTYVA-24-D      1681.33         1421.20        -260.13          775             689             86            0.73               0.73
# PRESPARTYIL-24-R       290.56          265.77         -24.79          114             104             10            0.81               0.83
# PRESPARTYCO-24-D       185.11          185.11           0.00           84              84              0            0.84               0.84
# PRESPARTYIN-24-D       180.45          180.45           0.00           67              67              0            0.88               0.88
# PRESPARTYIL-24-D       149.20          149.20           0.00           57              57              0            0.84               0.84
# PRESPARTYCO-24-R       139.06          126.73         -12.33           91              66             25            0.70               0.73
# PRESPARTYIN-24-R        99.33           99.33           0.00           35              35              0            0.89               0.89
# PRESPARTYMO-24-D        86.45           86.45           0.00           42              42              0            0.76               0.76
#    SENATEWI-24-R        82.84          119.01          36.17          520             419            101            0.53               0.54
#    SENATEWI-24-D      -219.17         -138.50          80.67          347             246            101            0.54               0.57
#
# Naive total: 24419.4c | Informed total: 23020.8c | Delta: -1398.6c
# Improved: 2/17 tickers

# %% [markdown]
# ## 6. Threshold Sweep

# %%
sweep_tkr = max(all_as.keys(), key=lambda k: len(all_as[k].prices))
sweep_df = sweep_thresholds(all_as[sweep_tkr], mtm_horizon_trades=60)
print(f"Threshold sweep: {sweep_tkr}")
print(sweep_df.to_string(index=False, float_format="%.2f"))

fig, ax = plt.subplots(figsize=(10, 4))
inf = sweep_df[sweep_df.strategy == "as_informed"]
ax.plot(inf.threshold, inf.net_pnl_c, "o-", color="#2ecc71", lw=2)
ax.axhline(sweep_df.iloc[0].net_pnl_c, color="red", ls="--", label="Naive")
ax.set_xlabel("tau"); ax.set_ylabel("PnL (c)"); ax.set_title("PnL vs AS Threshold"); ax.legend()
plt.tight_layout()
plt.savefig("../figures/election_threshold_sweep.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Threshold sweep: PRESPARTYPA-24-R
#  threshold    strategy  n_fills  n_pulled  net_pnl_c  pnl_per_fill_c  win_rate  gross_spread_c  mtm_pnl_c  fees_c
#       0.00       naive     2316         0    5204.29            2.25      0.84         4632.00    1348.00  775.71
#       0.10 as_informed     1629      6356    3729.42            2.29      0.85         3258.00    1032.00  560.58
#       0.20 as_informed     1630      6334    3729.99            2.29      0.85         3260.00    1031.00  561.01
#       0.30 as_informed     1632      6312    3736.27            2.29      0.85         3264.00    1034.00  561.73
#       0.40 as_informed     1916      4246    4302.60            2.25      0.85         3832.00    1128.00  657.40
#       0.50 as_informed     1921      4206    4316.91            2.25      0.85         3842.00    1134.00  659.09
#       0.60 as_informed     1924      4145    4315.08            2.24      0.85         3848.00    1127.00  659.92
#       0.70 as_informed     2181      1250    4936.35            2.26      0.85         4362.00    1307.00  732.65
#       0.80 as_informed     2182      1240    4946.05            2.27      0.85         4364.00    1315.00  732.95
#       0.90 as_informed     2184      1220    4948.46            2.27      0.85         4368.00    1314.00  733.54

# %% [markdown]
# ## 7. Cross-State Co-Jump Analysis
#
# Election night: when one state's results move, correlated markets (same party, swing states) may jump together.

# %%
g5 = {}
for tkr, ar in all_as.items():
    g5[tkr] = pd.Series(ar.gamma, index=pd.to_datetime(ar.timestamps)).resample("5min").max().dropna()
ga = pd.DataFrame(g5).dropna(thresh=2)
print(f"Co-jump analysis: {len(ga)} 5-min windows across {len(ga.columns)} states")
print("\nCross-correlation of gamma (5-min max):")
print(ga.corr().round(3).to_string())
# Out:
# Co-jump analysis: 6693 5-min windows across 17 states
#
# Cross-correlation of gamma (5-min max):
#                   PRESPARTYPA-24-R  PRESPARTYPA-24-D  PRESPARTYNV-24-R  PRESPARTYNV-24-D  PRESPARTYVA-24-R  PRESPARTYAZ-24-D  PRESPARTYAZ-24-R  PRESPARTYVA-24-D  SENATEWI-24-R  SENATEWI-24-D  PRESPARTYIL-24-R  PRESPARTYCO-24-R  PRESPARTYCO-24-D  PRESPARTYIL-24-D  PRESPARTYIN-24-D  PRESPARTYMO-24-D  PRESPARTYIN-24-R
# PRESPARTYPA-24-R             1.000             0.242             0.222             0.224             0.189             0.238             0.156             0.135          0.160          0.145            -0.007             0.160             0.105            -0.043             0.137            -0.117            -0.170
# PRESPARTYPA-24-D             0.242             1.000             0.232             0.260             0.228             0.257             0.220             0.134          0.143          0.167            -0.012             0.166             0.027            -0.072             0.129            -0.006            -0.017
# PRESPARTYNV-24-R             0.222             0.232             1.000             0.315             0.198             0.275             0.268             0.170          0.260          0.266             0.004             0.156             0.010            -0.024             0.012            -0.030            -0.200
# PRESPARTYNV-24-D             0.224             0.260             0.315             1.000             0.186             0.267             0.246             0.203          0.263          0.277             0.028             0.085             0.080            -0.062             0.115             0.009            -0.054
# PRESPARTYVA-24-R             0.189             0.228             0.198             0.186             1.000             0.221             0.197             0.207          0.202          0.139            -0.041             0.129             0.096            -0.058             0.136            -0.141            -0.007
# PRESPARTYAZ-24-D             0.238             0.257             0.275             0.267             0.221             1.000             0.315             0.225          0.364          0.401             0.028             0.138             0.189             0.073             0.048             0.067             0.044
# PRESPARTYAZ-24-R             0.156             0.220             0.268             0.246             0.197             0.315             1.000             0.195          0.296          0.286             0.067             0.178             0.071             0.036             0.059             0.034            -0.049
# PRESPARTYVA-24-D             0.135             0.134             0.170             0.203             0.207             0.225             0.195             1.000          0.229          0.310             0.013             0.164             0.177             0.044            -0.018             0.102            -0.035
# SENATEWI-24-R                0.160             0.143             0.260             0.263             0.202             0.364             0.296             0.229          1.000          0.439             0.072             0.080             0.228             0.123             0.094             0.104             0.065
# SENATEWI-24-D                0.145             0.167             0.266             0.277             0.139             0.401             0.286             0.310          0.439          1.000             0.009             0.092             0.241             0.160             0.296             0.141             0.013
# PRESPARTYIL-24-R            -0.007            -0.012             0.004             0.028            -0.041             0.028             0.067             0.013          0.072          0.009             1.000             0.034            -0.108             0.174             0.209            -0.088             0.095
# PRESPARTYCO-24-R             0.160             0.166             0.156             0.085             0.129             0.138             0.178             0.164          0.080          0.092             0.034             1.000             0.233             0.191             0.176             0.014            -0.236
# PRESPARTYCO-24-D             0.105             0.027             0.010             0.080             0.096             0.189             0.071             0.177          0.228          0.241            -0.108             0.233             1.000             0.265             0.105             0.107             0.036
# PRESPARTYIL-24-D            -0.043            -0.072            -0.024            -0.062            -0.058             0.073             0.036             0.044          0.123          0.160             0.174             0.191             0.265             1.000             0.156             0.186            -0.140
# PRESPARTYIN-24-D             0.137             0.129             0.012             0.115             0.136             0.048             0.059            -0.018          0.094          0.296             0.209             0.176             0.105             0.156             1.000             0.210             0.139
# PRESPARTYMO-24-D            -0.117            -0.006            -0.030             0.009            -0.141             0.067             0.034             0.102          0.104          0.141            -0.088             0.014             0.107             0.186             0.210             1.000            -0.206
# PRESPARTYIN-24-R            -0.170            -0.017            -0.200            -0.054            -0.007             0.044            -0.049            -0.035          0.065          0.013             0.095            -0.236             0.036            -0.140             0.139            -0.206             1.000

# %% [markdown]
# ## 8. Summary

# %%
print("=" * 70)
print("ADVERSE SELECTION — 2024 ELECTION MARKETS SUMMARY")
print("=" * 70)
tt = sum(len(ar.prices) for ar in all_as.values())
te = sum((ar.as_score > 0.9).sum() for ar in all_as.values())
print(f"Tickers: {len(all_as)} | Trades: {tt:,} | AS events: {te:,} ({te/tt*100:.1f}%)")
nt = sum(c.naive.net_pnl for c in comparisons.values())
it = sum(c.informed.net_pnl for c in comparisons.values())
print(f"Backtest (tau=0.9): Naive={nt:.1f}c Informed={it:.1f}c Delta={it-nt:+.1f}c")
improved = sum(1 for c in comparisons.values() if c.pnl_improvement > 0)
print(f"Improved: {improved}/{len(comparisons)} tickers")
print("=" * 70)
# Out:
# ======================================================================
# ADVERSE SELECTION — 2024 ELECTION MARKETS SUMMARY
# ======================================================================
# Tickers: 17 | Trades: 113,499 | AS events: 25,306 (22.3%)
# Backtest (tau=0.9): Naive=24419.4c Informed=23020.8c Delta=-1398.6c
# Improved: 2/17 tickers
# ======================================================================
